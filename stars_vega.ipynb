# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/astrophysics/blob/main/stars_vega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vega**

# %% [markdown]
# https://en.m.wikipedia.org/wiki/Vega
#
# https://pysynphot.readthedocs.io/en/latest/tutorials.html

# %% [markdown]
# ![ggg](https://upload.wikimedia.org/wikipedia/commons/2/27/LyraCC.jpg)

# %%
# !pip install pysynphot astropy -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 32.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !export PYSYN_CDBS=/my/local/dir/trds/

# %%
import os
os.environ['PYSYN_CDBS']
'/my/local/dir/trds/'
import numpy as np
import pysynphot as S
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-72f3c11948e1> in <cell line: 2>()
#       1 import os
# ----> 2 os.environ['PYSYN_CDBS']
#       3 '/my/local/dir/trds/'
#       4 import numpy as np
#       5 import pysynphot as S
#
# /usr/lib/python3.10/os.py in __getitem__(self, key)
#     678         except KeyError:
#     679             # raise KeyError with the original key value
# --> 680             raise KeyError(key) from None
#     681         return self.decodevalue(value)
#     682
#
# KeyError: 'PYSYN_CDBS'

# %%
vega_file = os.path.join(
    os.environ['PYSYN_CDBS'], 'calspec', 'alpha_lyr_stis_005.fits')
vega = S.FileSpectrum(vega_file)
vega.convert('flam')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-7885f1bd5ee6> in <cell line: 1>()
#       1 vega_file = os.path.join(
# ----> 2     os.environ['PYSYN_CDBS'], 'calspec', 'alpha_lyr_stis_005.fits')
#       3 vega = S.FileSpectrum(vega_file)
#       4 vega.convert('flam')
#
# /usr/lib/python3.10/os.py in __getitem__(self, key)
#     678         except KeyError:
#     679             # raise KeyError with the original key value
# --> 680             raise KeyError(key) from None
#     681         return self.decodevalue(value)
#     682
#
# KeyError: 'PYSYN_CDBS'
