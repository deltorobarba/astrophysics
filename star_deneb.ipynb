# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/astrophysics/blob/main/star_deneb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Star Deneb**

# %%
# !pip install astropy photutils astroquery lightkurve -q

# %%
from astropy import units as u
from astroquery.ipac.irsa import Irsa
import lightkurve as lk
from astroquery.vizier import Vizier
from astropy.coordinates import Angle
from astroquery.splatalogue import Splatalogue
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
# %matplotlib inline

# %% [markdown]
# https://learn.astropy.org/tutorials/1-SpectroscopicTraceTutorial.html

# %%
with open('requirements.txt') as f:
    print(f"Required packages for this notebook:\n{f.read()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-048ef18dcb01> in <cell line: 1>()
# ----> 1 with open('requirements.txt') as f:
#       2     print(f"Required packages for this notebook:\n{f.read()}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['image.origin'] = 'lower'
plt.style.use('dark_background') # Optional!

# %%
spectrum_filename = "aldebaran_3s_1.bmp"

# %%
image_data = Image.open(spectrum_filename)

# %%
image_array_2 = np.array(Image.open('deneb_3s_13.63g_1.bmp'))
plt.imshow(image_array_2, cmap='gray')
plt.colorbar();
